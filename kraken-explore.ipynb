# %%
import pandas as pd
import numpy as np

data = pd.read_csv("dataset/kraken-1mo.csv")
data.head()
# Out:
#     timestamp  microseconds side    close    volume
# 0  1768521600         97762    b  95559.5  0.000523
# 1  1768521600         97762    b  95567.4  0.000508
# 2  1768521600        166752    b  95569.7  0.000260
# 3  1768521600        188932    b  95569.7  0.000518
# 4  1768521600        212419    b  95569.7  0.001031

# %%
data.columns = ['timestamp', 'microseconds', 'side', 'close', 'volume']

# %%
data['side'] = data['side'].apply(lambda x: 1 if x == 'b' else 0)

# %%
data.to_csv("dataset/kraken-1mo-side.csv", index=False)
