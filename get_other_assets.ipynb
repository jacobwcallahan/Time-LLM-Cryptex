# %%
import yfinance as yf
import pandas as pd
import time
assets = ["ETH-USD", "XRP-USD", "DOGE-USD", "SOL-USD", "ADA-USD", "DOT-USD", "LINK-USD", "BCH-USD", "LTC-USD"]
assets = ["ETH-USD"]
for asset in assets:
    df = yf.download(asset, start="2024-01-01", end="2024-12-31", interval="1h")
    data = df.copy()
# Out:
# /tmp/ipykernel_414534/710330236.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(asset, start="2024-01-01", end="2024-12-31", interval="1h")
# [*********************100%***********************]  1 of 1 completed

# %%
#time.sleep(10)

# %%
data.head()
# Out:
#          close         open         high          low    volume   timestamp
# 0  2295.486328  2295.949951  2281.796631  2281.796631         0  1704067200
# 1  2303.165527  2305.132324  2293.775146  2295.244873  30413824  1704070800
# 2  2293.860596  2302.814453  2292.123535  2302.814453         0  1704074400
# 3  2273.409424  2293.799072  2272.324707  2293.439697  45711360  1704078000
# 4  2278.694092  2278.694092  2267.018066  2273.672119  89123840  1704081600
